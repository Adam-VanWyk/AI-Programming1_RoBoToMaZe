# %% [markdown]
# # Programming Exercise 2 : Heuristic Functions and Informed Search
#
# In this notebook you are going to find code and exercises for the second part of your programming exercises. For this part, we are going to continue working on your path-finding game, RoBoToMaZe!
#
# In the previous programming exerice, you focused on understanding the code for the game, its rules and implementation and you wrote a function for the Breadth-First Search algorithm, an uninformed search algorithm.
#
# Now we are going to assume that we have some knowledge regarding the distance of the goal cell from the robot cell, through path cost and heuristic functions.
#
# In brief, your tasks in this exercise are the following:
#
# - Write function to get the path cost from the robot's cell to the target cell
# - Write functions for the Manhattan Distance and the Euclidean Distance, to act as heuristic functions for the distance between the robot and the target
# - Update the game so that when we click on the robot position, we can see the Manhattan/Euclidean Distance to the target
# - Write function for the A* algorithm
#
# **What to submit?** A notebook with all the code, from programming 1, and the functions and additional code from this set of exercises (so that we can run the whole thing!)

# %% [markdown]
# > **Task 1 (20/100 Points):**
# >
# > You should have a BFS algorithm implementation for the RoBoToMaZe.
# >
# > Now, you need to write a function get_bfs_path, which can trace the path for the agent to follow from the robot to the goal. That is, given the list of visited cells, as returned by the BFS algorithm, the get_bfs_path function needs to be able to trace the path (in the tree stucture we saw in class, that would be, finding the path from the goal leaf to the root).
# >
# > For this, you will need another function that computes the Manhattan distance between two points. Given two points p1 and p2 on a 2-dimensional plane, with coordinates (x1,y1), (x2, y2) respectively, the Manhattan distance is defined as : |x1 - x2| + |y1 - y2|.
# >
# > Finish the code in the given functions as per the instructions.
# >
# > Grading: 5/20 Points are awarded for the correct implementation of the manhattan distance, 10/20 Poitns are awarded for a working implementation of the get_bfs_path functoin and 5/20 Points are awarded for making correct subtle decisions in your implementatoin as those are needed.

# %%
def manhattanD(cell_a, cell_b, cellSize):

        # Finish the function
    
    m_distance = 
    return m_distance

def get_bfs_path(start, visited, all_cells, cellSize, obstacles, goal_cell):
    ''' This function assumes it is used in connection with the code from programming 1.
    start : the initial location (coordinates) of the robot
    visited : the result of the bfs algorithm
    all_cells : the coordintes of all the cells in the grid
    cellSize : the size of each cell in the grid
    obstacles: the coordinates of the cells that are obstacles
    goal_cell : the coordinates of the target cell

    The function should return a list of coordinates that if followed,
    would lead one from the robot's initial position to the goal cell, through a sequence of legal moves
    '''

    path = []
    # Flag for the while loop    
    running = True

    # We will start backwards, from the goal cell and try to get to the starting location
    curr = goal_cell

    # the following should run until we reach the starting location of the robot
    # Logic to implement: get the valid neighbours of the current cell, then try to find which of these
    # are candidates to move to next - that is, must be in the visited structure.
    # From the candidates, pick the one that has the smallest distance to the starting location.
    # Add the picked candidate to the path, update the current cell to be the most recent candidate,
    # update the visited structure (you don't want to be going in circles) and check if the candidate is the
    # starting location
    # Alternative logic: during BFS, you should maintain a structure that keeps track of who is whose child/parent 
    # and use that structure in this function to trace back from the goal state to the initial one, along with the visited structure
    
    while running:
        # Finish the function

    return path

# %% [markdown]
# #### Path Cost
#
# The above function, can be used as inspiration for another function that computes the path cost from each cell to the goal. But, do we need to do that for **every** cell on the grid?
#
# The function you just completed can give you the overall path cost to the goal from the starting location of the robot. Now, you need to make sure we can get the path cost from any cell to the goal cell.
#
# >**Task 2 (20/100 Points):**
# >
# > Write a function path_cost that it will either return the path cost of a given cell to the goal cell, or it will return a dictionary where all the path costs for the necessary cells (all of them?) will be stored. The choice of implementation is yours!
# >
# >Notice that, unlike other tasks, here you also have to decide the parameters of the function on your own... Also notice that this task asks you to get the *actual* path cost between two cells - what does that mean about cells that are occupied by obstacles?
# >
# >Grading: 5/20 Points are awarded for the right parameters used in your path_cost function. 10/20 Points are awarded for the correct implementation and 5/20 Points are awarded for correct decisions during your implementation.

# %%
def path_cost():

    # Finish the function

# %% [markdown]
# ### Heuristic Functions
#
# Next, we are going to assume that we have some information about our space as we play the game (from the perspective of an agent). In particular, we are going to assume that each time we want to make a next move, we have available an estimation of the distance between each legal next step and the goal cell. This distance can be measured either through the Manhattan Distance or the Euclidean Distance. The next task is to write functions that will compute these distances.
#
# > **Task 3 (20/100 Points):**
# >
# > Finish the functions that calculate the Manhattan and the Euclidean distances respectively, between every legal next cell and the goal cell. Each function should return a dictionary of the distances (key should be a cell and its corresponding value the distance of the cell to the goal cell) sorted in ascending order.
# >
# > Grading: Each function is awarded 10/20 Points

# %%
def euclideanDistance(current_cell, all_cells, goal_cell, cellSize, obstacles):
    ''' Compute the Euclidean distance between every legal next cell and the goal cell.
    Since this is meant to act as a heuristic (estimation of the actual distance), obstacles are not
    taken into consideration as "obstacles".
    current_cell : the coordinates of the current location of the robot
    all_cells : the coordinates of all the cells in the grid
    goal_cell : the coordinates of the target cell
    cellSize : the size of a cell in the grid
    obstacles : the coordinates of the cells that are obstacles
    
    The function should return a dictionary where key,value is cell, distance of cell to goal cell, sorted in ascending order.
    '''
    x, y = current_cell
    xG, yG = goal_cell
    eDistances = {}
    
    # Finish the function
    # Compute the distance between the current cell and the goal cell
    # Then, compute the distance between every legal neighbour of the current cell and the goal cell
    # Store these in the eDistances dictionary and return it sorted in ascending order of the distances
     

def manhattanDistance(current_cell, all_cells, goal_cell, cellSize, obstacles):

    ''' Exactly the same as in the euclideanDistance function. 
    The only difference is that now you need to compute the Manhattan Distance. 
    The rest of the code would be pretty much the same as in the previous function.
    '''

# %% [markdown]
# #### Show distances on game
#
# Can you udpate the game so that, whenever you click on the current location of the robot, you get the legal next cells highlighted and on them, an estimation to the goal cell is shown? Something like that you see in the following images...
#
# ![image.png](attachment:d8b85ff4-2ca0-432c-abcb-b62eef3919fe.png) ![image.png](attachment:61a41f56-8c16-4e58-9d40-6a5d144c76e9.png)
#
# You can choose to implement this for the Euclidean or the Manhattan distance you completed in the previous task - it is up to you.
#
# > **Task 4 (20/100 Points):**
# >
# > Update the code in the main function so that, when the player clicks on the current cell of the robot, the manhattan/euclidean estimated distance to the goal is shown, from the current cell and from each legal neighbour. You can also make it so that when you click on the cell again, all that information disappears.
# >
# > This functionality should be added in the while loop of the main function of the game. Here is the logic that you need to implement:
# >
# > If one clicks on the cell that is currently the robot, then a flag must be activated. (this you should add in the block of code in the while loop where we check WHERE the mouse is clicked....)
# > Then (just before the pygame.display.update()) you need to write the code that implements what should happen when this flag is activated. That is, the distances of the required cells to be calculated and shown appropriately on top of the respective cells.
# >
# > Grading: 10/20 points are awarded for a good implementation of the task's logic, 5/20 Points are awarded for correctly adding the functionality in the main function and 5/20 Points are awarded for the right use of display of the values on the game's canvas.

# %%
## Add the code for Task 4 here for grading, but also in the full game implementation

# %% [markdown]
# #### A* Algorithm
#
# Can we write a function that implements the A* algorithm for our game? For that, we need to define an evaluation function
#
# f(s_i) = g(s_i) + h(s_i)
#
# where
#
# - g(s_i) is the total *actual* Path-cost to reach the current cell (s_i) from the starting cell (s_0)
# - h(s_i) is estimated cost to reach the goal cell from the current cell (s_i)
#
# For h() you can choose either the Manhattan or the Euclidean distance, up to you.
#
# > **Task 5 (20/100 Points):**
# >
# > 1. [15 Points] Write a function a_star that implements the evaluation function used in the A* algorithm. The function, given the current location of the robot, should compute and return f() = g() + h().
# > 2. [5 Points] Update your code so that now, whenever you click on the current cell, the values g and h appear on the current cell and the legal neighbouring cells.

# %%
def a_star(current_cell):

    # Finish the code
    
    return f
